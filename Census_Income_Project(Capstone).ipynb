# %% [markdown]
# <a href="https://colab.research.google.com/github/rupaidutta66/MACHINE-LEARNING-PROJECTS-/blob/main/Census_Income_Project(Capstone).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Income Classification Model**
#
# ###**Introduction**
#
# The income dataset was extracted from 1994 U.S. Census database.
#
# ###**Objective of the porject**
#
# The goal of this machine learning project is to predict whether a person makes over 50K a year or not given their demographic variation. To achieve this, several classification techniques are explored and the random forest model yields to the best prediction result.
#
# *Source:*
#
# [adult data set](https://https://archive.ics.uci.edu/ml/datasets/adult/)
#
# [Income dataset](http://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import sklearn 
# %matplotlib inline

# %%
cens = pd.read_csv('/content/census-income.csv')

# %%
cens.head()
# Out:
#    age          workclass   fnlwgt   education   education-num  \
# 0   39          State-gov    77516   Bachelors              13
# 1   50   Self-emp-not-inc    83311   Bachelors              13
# 2   38            Private   215646     HS-grad               9
# 3   53            Private   234721        11th               7
# 4   28            Private   338409   Bachelors              13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#     capital-gain   capital-loss   hours-per-week  native-country
# 0           2174              0               40   United-States   <=50K
# 1              0              0               13   United-States   <=50K
# 2              0              0               40   United-States   <=50K
# 3              0              0               40   United-States   <=50K
# 4              0              0               40            Cuba   <=50K

# %%
 cens.rename(columns={' ':'Income'}, inplace = True)

# %%
cens.head()
# Out:
#    age          workclass   fnlwgt   education   education-num  \
# 0   39          State-gov    77516   Bachelors              13
# 1   50   Self-emp-not-inc    83311   Bachelors              13
# 2   38            Private   215646     HS-grad               9
# 3   53            Private   234721        11th               7
# 4   28            Private   338409   Bachelors              13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#     capital-gain   capital-loss   hours-per-week  native-country  Income
# 0           2174              0               40   United-States   <=50K
# 1              0              0               13   United-States   <=50K
# 2              0              0               40   United-States   <=50K
# 3              0              0               40   United-States   <=50K
# 4              0              0               40            Cuba   <=50K

# %%
cens.shape
# Out:
# (32561, 15)

# %% [markdown]
# #**1. Data Preprocessing:**
#
# a) Replace all the missing values with NA.
#
# b) Remove all the rows that contain NA values.

# %%
cens.isnull().sum()
# Out:
# age                0
#  workclass         0
#  fnlwgt            0
#  education         0
#  education-num     0
#  marital-status    0
#  occupation        0
#  relationship      0
#  race              0
#  sex               0
#  capital-gain      0
#  capital-loss      0
#  hours-per-week    0
#  native-country    0
# Income             0
# dtype: int64

# %% [markdown]
# #**2. Data Manipulation:**

# %%
# a)Extract the “education” column and store it in “census_ed” .

census_ed = cens[[' education']]
census_ed
# Out:
#          education
# 0        Bachelors
# 1        Bachelors
# 2          HS-grad
# 3             11th
# 4        Bachelors
# ...            ...
# 32556   Assoc-acdm
# 32557      HS-grad
# 32558      HS-grad
# 32559      HS-grad
# 32560      HS-grad
#
# [32561 rows x 1 columns]

# %%
## b)Extract all the columns from “age” to “relationship” and store it in “census_seq”.

cesnus_seq = cens.loc[:,'age':' relationship']
cesnus_seq
# Out:
#        age          workclass   fnlwgt    education   education-num  \
# 0       39          State-gov    77516    Bachelors              13
# 1       50   Self-emp-not-inc    83311    Bachelors              13
# 2       38            Private   215646      HS-grad               9
# 3       53            Private   234721         11th               7
# 4       28            Private   338409    Bachelors              13
# ...    ...                ...      ...          ...             ...
# 32556   27            Private   257302   Assoc-acdm              12
# 32557   40            Private   154374      HS-grad               9
# 32558   58            Private   151910      HS-grad               9
# 32559   22            Private   201490      HS-grad               9
# 32560   52       Self-emp-inc   287927      HS-grad               9
#
#             marital-status          occupation    relationship
# 0            Never-married        Adm-clerical   Not-in-family
# 1       Married-civ-spouse     Exec-managerial         Husband
# 2                 Divorced   Handlers-cleaners   Not-in-family
# 3       Married-civ-spouse   Handlers-cleaners         Husband
# 4       Married-civ-spouse      Prof-specialty            Wife
# ...                    ...                 ...             ...
# 32556   Married-civ-spouse        Tech-support            Wife
# 32557   Married-civ-spouse   Machine-op-inspct         Husband
# 32558              Widowed        Adm-clerical       Unmarried
# 32559        Never-married        Adm-clerical       Own-child
# 32560   Married-civ-spouse     Exec-managerial            Wife
#
# [32561 rows x 8 columns]

# %%
### c)Extract the column number “5”, “8”, “11” and store it in “census_col”.

census_col = cens.iloc[:,[4,7,10]]  #notebly, here due to indexing concept we use one less the the actual column number.
census_col
# Out:
#         education-num    relationship   capital-gain
# 0                  13   Not-in-family           2174
# 1                  13         Husband              0
# 2                   9   Not-in-family              0
# 3                   7         Husband              0
# 4                  13            Wife              0
# ...               ...             ...            ...
# 32556              12            Wife              0
# 32557               9         Husband              0
# 32558               9       Unmarried              0
# 32559               9       Own-child              0
# 32560               9            Wife          15024
#
# [32561 rows x 3 columns]

# %%
#### d) Extract all the male employees who work in state-gov and store it in “male_gov”.

male_gov = cens[(cens[' sex']==' Male') & (cens[' workclass']==' State-gov')]
male_gov
# Out:
#        age   workclass   fnlwgt      education   education-num  \
# 0       39   State-gov    77516      Bachelors              13
# 11      30   State-gov   141297      Bachelors              13
# 34      22   State-gov   311512   Some-college              10
# 48      41   State-gov   101603      Assoc-voc              11
# 123     29   State-gov   267989      Bachelors              13
# ...    ...         ...      ...            ...             ...
# 32163   36   State-gov   135874      Bachelors              13
# 32241   45   State-gov   231013      Bachelors              13
# 32321   54   State-gov   138852        HS-grad               9
# 32324   42   State-gov   138162   Some-college              10
# 32360   58   State-gov   200316        HS-grad               9
#
#             marital-status        occupation    relationship  \
# 0            Never-married      Adm-clerical   Not-in-family
# 11      Married-civ-spouse    Prof-specialty         Husband
# 34      Married-civ-spouse     Other-service         Husband
# 48      Married-civ-spouse      Craft-repair         Husband
# 123     Married-civ-spouse    Prof-specialty         Husband
# ...                    ...               ...             ...
# 32163   Married-civ-spouse             Sales         Husband
# 32241             Divorced   Protective-serv   Not-in-family
# 32321   Married-civ-spouse    Prof-specialty         Husband
# 32324             Divorced      Adm-clerical       Own-child
# 32360   Married-civ-spouse      Craft-repair         Husband
#
#                       race    sex   capital-gain   capital-loss  \
# 0                    White   Male           2174              0
# 11      Asian-Pac-Islander   Male              0              0
# 34                   Black   Male              0              0
# 48                   White   Male              0              0
# 123                  White   Male              0              0
# ...                    ...    ...            ...            ...
# 32163                White   Male              0              0
# 32241                White   Male              0              0
# 32321                White   Male              0              0
# 32324                White   Male              0              0
# 32360                White   Male              0              0
#
#         hours-per-week  native-country  Income
# 0                   40   United-States   <=50K
# 11                  40           India    >50K
# 34                  15   United-States   <=50K
# 48                  40   United-States   <=50K
# 123                 50   United-States    >50K
# ...                ...             ...     ...
# 32163               40   United-States   <=50K
# 32241               40   United-States   <=50K
# 32321               40   United-States   <=50K
# 32324               40   United-States   <=50K
# 32360               40   United-States   <=50K
#
# [809 rows x 15 columns]

# %%
## e)Extract all the 39 year olds who either have a bachelor's degree or who are native of the United States and store the result in “census_us”.

census_us = cens[(cens.age==39) & ((cens[' education']==' Bachelors') | (cens[' native-country']==' United-States'))]
census_us
# Out:
#        age          workclass   fnlwgt      education   education-num  \
# 0       39          State-gov    77516      Bachelors              13
# 28      39            Private   367260        HS-grad               9
# 129     39            Private   365739   Some-college              10
# 166     39        Federal-gov   235485     Assoc-acdm              12
# 320     39   Self-emp-not-inc   174308        HS-grad               9
# ...    ...                ...      ...            ...             ...
# 32146   39            Private   117381   Some-college              10
# 32260   39        Federal-gov   232036   Some-college              10
# 32428   39        Federal-gov   110622      Bachelors              13
# 32468   39   Self-emp-not-inc   193689        HS-grad               9
# 32545   39          Local-gov   111499     Assoc-acdm              12
#
#             marital-status         occupation    relationship  \
# 0            Never-married       Adm-clerical   Not-in-family
# 28                Divorced    Exec-managerial   Not-in-family
# 129               Divorced       Craft-repair   Not-in-family
# 166          Never-married    Exec-managerial   Not-in-family
# 320     Married-civ-spouse    Exec-managerial         Husband
# ...                    ...                ...             ...
# 32146             Divorced   Transport-moving   Not-in-family
# 32260   Married-civ-spouse       Adm-clerical         Husband
# 32428   Married-civ-spouse       Adm-clerical            Wife
# 32468        Never-married    Exec-managerial   Not-in-family
# 32545   Married-civ-spouse       Adm-clerical            Wife
#
#                       race      sex   capital-gain   capital-loss  \
# 0                    White     Male           2174              0
# 28                   White     Male              0              0
# 129                  White     Male              0              0
# 166                  White     Male              0              0
# 320                  White     Male              0              0
# ...                    ...      ...            ...            ...
# 32146                White     Male              0              0
# 32260                White     Male              0              0
# 32428   Asian-Pac-Islander   Female              0              0
# 32468                White     Male              0              0
# 32545                White   Female              0              0
#
#         hours-per-week  native-country  Income
# 0                   40   United-States   <=50K
# 28                  80   United-States   <=50K
# 129                 40   United-States   <=50K
# 166                 42   United-States   <=50K
# 320                 40   United-States   <=50K
# ...                ...             ...     ...
# 32146               65   United-States   <=50K
# 32260               40   United-States    >50K
# 32428               40     Philippines   <=50K
# 32468               65   United-States   <=50K
# 32545               20   United-States    >50K
#
# [759 rows x 15 columns]

# %%
## f) Extract 200 random rows from the “census” data frame and store it in “census_200”.

census_200 = cens.sample(200)
census_200
# Out:
#        age      workclass   fnlwgt    education   education-num  \
# 12793   33        Private   236396    Bachelors              13
# 8076    50   Self-emp-inc   136913      HS-grad               9
# 489     38        Private    91039    Bachelors              13
# 27326   21        Private   222993      HS-grad               9
# 30849   42      State-gov   212027    Bachelors              13
# ...    ...            ...      ...          ...             ...
# 8111    21        Private    34918      HS-grad               9
# 14057   24        Private    52242      HS-grad               9
# 15937   34      State-gov   287908      HS-grad               9
# 21237   37        Private   305259   Assoc-acdm              12
# 3996    54      State-gov   198186      HS-grad               9
#
#             marital-status          occupation    relationship    race  \
# 12793   Married-civ-spouse               Sales         Husband   White
# 8076    Married-civ-spouse     Farming-fishing         Husband   White
# 489     Married-civ-spouse               Sales         Husband   White
# 27326        Never-married   Machine-op-inspct       Own-child   White
# 30849             Divorced      Prof-specialty   Not-in-family   Black
# ...                    ...                 ...             ...     ...
# 8111         Never-married               Sales       Own-child   White
# 14057   Married-civ-spouse               Sales            Wife   White
# 15937        Never-married       Other-service       Own-child   Black
# 21237             Divorced     Exec-managerial   Not-in-family   White
# 3996         Never-married       Other-service   Not-in-family   Black
#
#            sex   capital-gain   capital-loss   hours-per-week  native-country  \
# 12793     Male              0           1902               55   United-States
# 8076      Male              0              0               50   United-States
# 489       Male          15024              0               60   United-States
# 27326     Male              0              0               40   United-States
# 30849     Male              0              0               40   United-States
# ...        ...            ...            ...              ...             ...
# 8111    Female              0              0               30   United-States
# 14057   Female              0              0               40   United-States
# 15937     Male              0              0               42   United-States
# 21237   Female              0              0               48   United-States
# 3996    Female              0              0               38   United-States
#
#        Income
# 12793    >50K
# 8076    <=50K
# 489      >50K
# 27326   <=50K
# 30849   <=50K
# ...       ...
# 8111    <=50K
# 14057    >50K
# 15937   <=50K
# 21237   <=50K
# 3996    <=50K
#
# [200 rows x 15 columns]

# %%
## g) Get the count of different levels of the “workclass” column

cens[' workclass'].value_counts()
# Out:
#  Private             22696
#  Self-emp-not-inc     2541
#  Local-gov            2093
#  ?                    1836
#  State-gov            1298
#  Self-emp-inc         1116
#  Federal-gov           960
#  Without-pay            14
#  Never-worked            7
# Name:  workclass, dtype: int64

# %%
# h) Calculate the mean of the “capital.gain” column grouped according to “workclass”.

cens.groupby(' workclass')[' capital-gain'].mean()
# Out:
#  workclass
#  ?                    606.795752
#  Federal-gov          833.232292
#  Local-gov            880.202580
#  Never-worked           0.000000
#  Private              889.217792
#  Self-emp-inc        4875.693548
#  Self-emp-not-inc    1886.061787
#  State-gov            701.699538
#  Without-pay          487.857143
# Name:  capital-gain, dtype: float64

# %%
## i)Create a separate dataframe with the details of males and females from the census data that has income more than 50,000.

cens['Income'] = cens.Income.replace(' <=50K', 0)
cens['Income'] = cens.Income.replace(' >50K', 1)

# %%
male_50k=cens[(cens[' sex']==' Male') & (cens['Income']==1)]
male_50k
# Out:
#        age          workclass   fnlwgt      education   education-num  \
# 7       52   Self-emp-not-inc   209642        HS-grad               9
# 9       42            Private   159449      Bachelors              13
# 10      37            Private   280464   Some-college              10
# 11      30          State-gov   141297      Bachelors              13
# 14      40            Private   121772      Assoc-voc              11
# ...    ...                ...      ...            ...             ...
# 32532   34            Private   204461      Doctorate              16
# 32533   54            Private   337992      Bachelors              13
# 32539   71                  ?   287372      Doctorate              16
# 32554   53            Private   321865        Masters              14
# 32557   40            Private   154374        HS-grad               9
#
#             marital-status          occupation  relationship  \
# 7       Married-civ-spouse     Exec-managerial       Husband
# 9       Married-civ-spouse     Exec-managerial       Husband
# 10      Married-civ-spouse     Exec-managerial       Husband
# 11      Married-civ-spouse      Prof-specialty       Husband
# 14      Married-civ-spouse        Craft-repair       Husband
# ...                    ...                 ...           ...
# 32532   Married-civ-spouse      Prof-specialty       Husband
# 32533   Married-civ-spouse     Exec-managerial       Husband
# 32539   Married-civ-spouse                   ?       Husband
# 32554   Married-civ-spouse     Exec-managerial       Husband
# 32557   Married-civ-spouse   Machine-op-inspct       Husband
#
#                       race    sex   capital-gain   capital-loss  \
# 7                    White   Male              0              0
# 9                    White   Male           5178              0
# 10                   Black   Male              0              0
# 11      Asian-Pac-Islander   Male              0              0
# 14      Asian-Pac-Islander   Male              0              0
# ...                    ...    ...            ...            ...
# 32532                White   Male              0              0
# 32533   Asian-Pac-Islander   Male              0              0
# 32539                White   Male              0              0
# 32554                White   Male              0              0
# 32557                White   Male              0              0
#
#         hours-per-week  native-country  Income
# 7                   45   United-States       1
# 9                   40   United-States       1
# 10                  80   United-States       1
# 11                  40           India       1
# 14                  40               ?       1
# ...                ...             ...     ...
# 32532               60   United-States       1
# 32533               50           Japan       1
# 32539               10   United-States       1
# 32554               40   United-States       1
# 32557               40   United-States       1
#
# [6662 rows x 15 columns]

# %%
female_50k=cens[(cens[' sex']==' Female') & (cens['Income']==1)]
female_50k
# Out:
#        age          workclass   fnlwgt     education   education-num  \
# 8       31            Private    45781       Masters              14
# 19      43   Self-emp-not-inc   292175       Masters              14
# 52      47            Private    51835   Prof-school              15
# 67      53            Private   169846       HS-grad               9
# 84      44            Private   343591       HS-grad               9
# ...    ...                ...      ...           ...             ...
# 32530   35                  ?   320084     Bachelors              13
# 32536   34            Private   160216     Bachelors              13
# 32538   38            Private   139180     Bachelors              13
# 32545   39          Local-gov   111499    Assoc-acdm              12
# 32560   52       Self-emp-inc   287927       HS-grad               9
#
#             marital-status        occupation    relationship    race      sex  \
# 8            Never-married    Prof-specialty   Not-in-family   White   Female
# 19                Divorced   Exec-managerial       Unmarried   White   Female
# 52      Married-civ-spouse    Prof-specialty            Wife   White   Female
# 67      Married-civ-spouse      Adm-clerical            Wife   White   Female
# 84                Divorced      Craft-repair   Not-in-family   White   Female
# ...                    ...               ...             ...     ...      ...
# 32530   Married-civ-spouse                 ?            Wife   White   Female
# 32536        Never-married   Exec-managerial   Not-in-family   White   Female
# 32538             Divorced    Prof-specialty       Unmarried   Black   Female
# 32545   Married-civ-spouse      Adm-clerical            Wife   White   Female
# 32560   Married-civ-spouse   Exec-managerial            Wife   White   Female
#
#         capital-gain   capital-loss   hours-per-week  native-country  Income
# 8              14084              0               50   United-States       1
# 19                 0              0               45   United-States       1
# 52                 0           1902               60        Honduras       1
# 67                 0              0               40   United-States       1
# 84             14344              0               40   United-States       1
# ...              ...            ...              ...             ...     ...
# 32530              0              0               55   United-States       1
# 32536              0              0               55   United-States       1
# 32538          15020              0               45   United-States       1
# 32545              0              0               20   United-States       1
# 32560          15024              0               40   United-States       1
#
# [1179 rows x 15 columns]

# %%
### j) Calculate the percentage of people from the United States who are private employees and earn less than 50,000 annually.

total = cens[' workclass'].value_counts().sum()
p_le50k=cens[(cens[' native-country']==' United-States') & (cens[' workclass']==' Private') &(cens['Income']==0)]

percentage = (len(p_le50k)/total)*100
print(' The percentage of people from the United States who are private employees and earn less than 50,000 annually is {}'.format(percentage))
# Out:
#  The percentage of people from the United States who are private employees and earn less than 50,000 annually is 47.891649519363654

# %%
## k) Calculate the percentage of married people in the census data.

cens[' marital-status']= cens[' marital-status'].replace([' Married-civ-spouse', ' Married-AF-spouse',' Married-spouse-absent'], 'married')
cens[' marital-status'].value_counts()
# Out:
# married           15417
#  Never-married    10683
#  Divorced          4443
#  Separated         1025
#  Widowed            993
# Name:  marital-status, dtype: int64

# %%
total=len(cens[' marital-status'])
n_married = len(cens[cens[' marital-status']=='married'])
perc_married = (n_married/total)*100
perc_married
# Out:
# 47.34805442093302

# %%
# l) Calculate the percentage of high school graduates earning more than 50,000 annually.

hs_m50k=len(cens[(cens[' education']==' HS-grad') &(cens['Income']==1)])
total=len(cens[' education'])
perc_edu = (hs_m50k/total)*100
perc_edu
# Out:
# 5.144190903227788

# %% [markdown]
# #**Feature Engineering**

# %%
# education Category
cens[' education'] = cens[' education'].replace([' Preschool', ' 1st-4th', ' 5th-6th', ' 7th-8th', ' 9th',' 10th', ' 11th', ' 12th'], 'school')
cens[' education'] = cens[' education'].replace([' HS-grad'], 'high school')
cens[' education'] = cens[' education'].replace([' Bachelors'], 'undergrad')
cens[' education'] = cens[' education'].replace([' Masters'], 'grad')
cens[' education'] = cens[' education'].replace([' Doctorate'], 'doc')

# %%
#martial status

cens[' marital-status']= cens[' marital-status'].replace([' Never-married'], 'not-married')
cens[' marital-status']= cens[' marital-status'].replace([' Divorced', ' Separated','Widowed'], 'other')

# %%
cens.head()
# Out:
#    age          workclass   fnlwgt    education   education-num  \
# 0   39          State-gov    77516    undergrad              13
# 1   50   Self-emp-not-inc    83311    undergrad              13
# 2   38            Private   215646  high school               9
# 3   53            Private   234721       school               7
# 4   28            Private   338409    undergrad              13
#
#    marital-status          occupation    relationship    race      sex  \
# 0     not-married        Adm-clerical   Not-in-family   White     Male
# 1         married     Exec-managerial         Husband   White     Male
# 2           other   Handlers-cleaners   Not-in-family   White     Male
# 3         married   Handlers-cleaners         Husband   Black     Male
# 4         married      Prof-specialty            Wife   Black   Female
#
#     capital-gain   capital-loss   hours-per-week  native-country  Income
# 0           2174              0               40   United-States       0
# 1              0              0               13   United-States       0
# 2              0              0               40   United-States       0
# 3              0              0               40   United-States       0
# 4              0              0               40            Cuba       0

# %%
cens[' workclass'].value_counts()
# Out:
#  Private             22696
#  Self-emp-not-inc     2541
#  Local-gov            2093
#  ?                    1836
#  State-gov            1298
#  Self-emp-inc         1116
#  Federal-gov           960
#  Without-pay            14
#  Never-worked            7
# Name:  workclass, dtype: int64

# %%
cens[' occupation'].value_counts()
# Out:
#  Prof-specialty       4140
#  Craft-repair         4099
#  Exec-managerial      4066
#  Adm-clerical         3770
#  Sales                3650
#  Other-service        3295
#  Machine-op-inspct    2002
#  ?                    1843
#  Transport-moving     1597
#  Handlers-cleaners    1370
#  Farming-fishing       994
#  Tech-support          928
#  Protective-serv       649
#  Priv-house-serv       149
#  Armed-Forces            9
# Name:  occupation, dtype: int64

# %%
cens[' native-country'].value_counts()
# Out:
#  United-States                 29170
#  Mexico                          643
#  ?                               583
#  Philippines                     198
#  Germany                         137
#  Canada                          121
#  Puerto-Rico                     114
#  El-Salvador                     106
#  India                           100
#  Cuba                             95
#  England                          90
#  Jamaica                          81
#  South                            80
#  China                            75
#  Italy                            73
#  Dominican-Republic               70
#  Vietnam                          67
#  Guatemala                        64
#  Japan                            62
#  Poland                           60
#  Columbia                         59
#  Taiwan                           51
#  Haiti                            44
#  Iran                             43
#  Portugal                         37
#  Nicaragua                        34
#  Peru                             31
#  France                           29
#  Greece                           29
#  Ecuador                          28
#  Ireland                          24
#  Hong                             20
#  Cambodia                         19
#  Trinadad&Tobago                  19
#  Laos                             18
#  Thailand                         18
#  Yugoslavia                       16
#  Outlying-US(Guam-USVI-etc)       14
#  Honduras                         13
#  Hungary                          13
#  Scotland                         12
#  Holand-Netherlands                1
# Name:  native-country, dtype: int64

# %%
# changing "?" to Unknown

change_columns = [' workclass', ' occupation', ' native-country']
for column in change_columns:
        cens[column] = cens[column].replace({'?': 'Unknown'})

# %% [markdown]
# #**Data Preprocessing**

# %%
cens_prep = cens.copy()# We have taken a copy of the dataset to maintain the cleaned one for later uses, and to use the copied one for preparing the data for the model.

# %%
from sklearn.preprocessing import MinMaxScaler
numerical = ['age', ' capital-gain', ' capital-loss', ' hours-per-week', ' fnlwgt']

scaler = MinMaxScaler()
cens_prep[numerical] = scaler.fit_transform(cens_prep[numerical])

# %%
cens_prep[' sex'] = cens_prep[' sex'].replace({" Female": 0, " Male": 1})

# %%
cens_prep.sample(3)
# Out:
#             age  workclass    fnlwgt      education   education-num  \
# 15694  0.219178    Private  0.115942   Some-college              10
# 18370  0.178082    Private  0.015864         school               7
# 15957  0.082192    Private  0.344974   Some-college              10
#
#        marital-status          occupation    relationship    race   sex  \
# 15694     not-married       Other-service   Not-in-family   White     1
# 18370         married   Handlers-cleaners         Husband   White     1
# 15957     not-married      Prof-specialty   Not-in-family   White     0
#
#         capital-gain   capital-loss   hours-per-week  native-country  Income
# 15694            0.0            0.0         0.234694   United-States       0
# 18370            0.0            0.0         0.500000   United-States       0
# 15957            0.0            0.0         0.448980   United-States       0

# %% [markdown]
# #**3. Linear Regression:**
#
# 3. Linear Regression:
#
# a) Build a simple linear regression model as follows:
#
# ●	Divide the dataset into training and test sets in 70:30 ratio.
#
# ●	Build a linear model on the test set where the dependent variable is “hours.per.week” and the independent variable is “education.num”.
#
# ●	Predict the values on the train set and find the error in prediction.
#
# ●	Find the root-mean-square error (RMSE).

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
#independent variable is “education.num”.
x=cens_prep[[' education-num']]
#dependent variable is “hours.per.week”
y=cens_prep[' hours-per-week']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=.30, random_state=1)

# %%
lr = LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(x_test)

# %%
error = y_test - y_pred
error
# Out:
# 9646     0.306580
# 709     -0.134278
# 7385     0.075842
# 16671    0.003789
# 21932    0.018783
#            ...
# 29663   -0.018702
# 29310    0.003789
# 29661   -0.003708
# 19491   -0.011205
# 2861     0.056268
# Name:  hours-per-week, Length: 9769, dtype: float64

# %%
print('mean_squared_error :',mean_squared_error(y_test,y_pred))

print('root-mean-square error :',np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# mean_squared_error : 0.015322013576285046
# root-mean-square error : 0.12378212139192415

# %% [markdown]
# #**4. Logistic Regression:**
#
# a) Build a simple logistic regression model as follows:
#
# ●	Divide the dataset into training and test sets in 65:35 ratio.
#
# ●	Build a logistic regression model where the dependent variable is “X”(yearly income) and the independent variable is “occupation”.
#
# ●	Predict the values on the test set.
#
# ●	Build a confusion matrix and find the accuracy.**

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
x=cens[' occupation']
x=pd.DataFrame(x)

# %%
x
# Out:
#                occupation
# 0            Adm-clerical
# 1         Exec-managerial
# 2       Handlers-cleaners
# 3       Handlers-cleaners
# 4          Prof-specialty
# ...                   ...
# 32556        Tech-support
# 32557   Machine-op-inspct
# 32558        Adm-clerical
# 32559        Adm-clerical
# 32560     Exec-managerial
#
# [32561 rows x 1 columns]

# %%
le=LabelEncoder()
X=le.fit_transform(x)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_label.py:115: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
X=pd.DataFrame(X)

# %%
X.head()
# Out:
#     0
# 0   1
# 1   4
# 2   6
# 3   6
# 4  10

# %%
y=cens['Income']
y.values.reshape(-1,1)
# Out:
# array([[0],
#        [0],
#        [0],
#        ...,
#        [0],
#        [0],
#        [1]])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.35, random_state=1)

lo=LogisticRegression()

# %%
lo.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=lo.predict(X_test)

# %%
print('confusion_matrix :')
print(confusion_matrix(y_pred,y_test))
print('accuracy_score :',accuracy_score(y_test,y_pred))
# Out:
# confusion_matrix :
# [[8800 2597]
#  [   0    0]]
# accuracy_score : 0.7721330174607353

# %% [markdown]
# b)Build a multiple logistic regression model as follows:
#
# ●-	Divide the dataset into training and test sets in 80:20 ratio.
#
# ●-	Build a logistic regression model where the dependent variable is “X”
# (yearly income) and independent variables are “age”, “workclass”, and “education”.
#
# ●-	Predict the values on the test set.
#
# ●-	Build a confusion matrix and find the accuracy

# %%
census=cens[['age',' workclass',' education']]
census
# Out:
#        age          workclass    education
# 0       39          State-gov    undergrad
# 1       50   Self-emp-not-inc    undergrad
# 2       38            Private  high school
# 3       53            Private       school
# 4       28            Private    undergrad
# ...    ...                ...          ...
# 32556   27            Private   Assoc-acdm
# 32557   40            Private  high school
# 32558   58            Private  high school
# 32559   22            Private  high school
# 32560   52       Self-emp-inc  high school
#
# [32561 rows x 3 columns]

# %%
x=census.apply(le.fit_transform)
y=cens['Income']
y.values.reshape(-1,1)
# Out:
# array([[0],
#        [0],
#        [0],
#        ...,
#        [0],
#        [0],
#        [1]])

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=.20, random_state=1)
lo=LogisticRegression()
lo.fit(x_train,y_train)
y_pred=lo.predict(x_test)

print('confusion_matrix :')
print(confusion_matrix(y_pred,y_test))
print('accuracy_score :',accuracy_score(y_test,y_pred))
# Out:
# confusion_matrix :
# [[4919 1457]
#  [ 107   30]]
# accuracy_score : 0.7598648856133886

# %% [markdown]
# #**5. Decision Tree:**
# a) Build a decision tree model as follows:
#
# ●	Divide the dataset into training and test sets in 70:30 ratio.
#
# ●	Build a decision tree model where the dependent variable is “X”(Yearly Income) and the rest of the variables as independent variables.
#
# ●	Predict the values on the test set.
#
# ●	Build a confusion matrix and calculate the accuracy.

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
cens_prep.head()
# Out:
#         age          workclass    fnlwgt    education   education-num  \
# 0  0.301370          State-gov  0.044302    undergrad              13
# 1  0.452055   Self-emp-not-inc  0.048238    undergrad              13
# 2  0.287671            Private  0.138113  high school               9
# 3  0.493151            Private  0.151068       school               7
# 4  0.150685            Private  0.221488    undergrad              13
#
#    marital-status          occupation    relationship    race   sex  \
# 0     not-married        Adm-clerical   Not-in-family   White     1
# 1         married     Exec-managerial         Husband   White     1
# 2           other   Handlers-cleaners   Not-in-family   White     1
# 3         married   Handlers-cleaners         Husband   Black     1
# 4         married      Prof-specialty            Wife   Black     0
#
#     capital-gain   capital-loss   hours-per-week  native-country  Income
# 0        0.02174            0.0         0.397959   United-States       0
# 1        0.00000            0.0         0.122449   United-States       0
# 2        0.00000            0.0         0.397959   United-States       0
# 3        0.00000            0.0         0.397959   United-States       0
# 4        0.00000            0.0         0.397959            Cuba       0

# %%
data=cens_prep.apply(le.fit_transform)
data.head()
# Out:
#    age   workclass   fnlwgt   education   education-num   marital-status  \
# 0   22           7     2671           8              12                2
# 1   33           6     2926           8              12                1
# 2   21           4    14086           6               8                3
# 3   36           4    15336           7               6                1
# 4   11           4    19355           8              12                1
#
#     occupation   relationship   race   sex   capital-gain   capital-loss  \
# 0            1              1      4     1             25              0
# 1            4              0      4     1              0              0
# 2            6              1      4     1              0              0
# 3            6              0      2     1              0              0
# 4           10              5      2     0              0              0
#
#     hours-per-week   native-country  Income
# 0               39               39       0
# 1               12               39       0
# 2               39               39       0
# 3               39               39       0
# 4               39                5       0

# %%
#independent
x=data.iloc[:,:-1]
#dependent
y=data.iloc[:,-1]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=.30, random_state=1)
dt=DecisionTreeClassifier()
dt.fit(x_train,y_train)
y_pred=dt.predict(x_test)

print('confusion_matrix :')
print(confusion_matrix(y_pred,y_test))
print('accuracy_score :',accuracy_score(y_test,y_pred))
# Out:
# confusion_matrix :
# [[6548  855]
#  [1002 1364]]
# accuracy_score : 0.8099088954857201

# %% [markdown]
# #**6. Random Forest:**
# a) Build a random forest model as follows:
#
# ●	Divide the dataset into training and test sets in 80:20 ratio.
#
# ●	Build a random forest model where the dependent variable is “X”(Yearly Income) and the rest of the variables as independent variables and number of trees as 300.
#
# ●	Predict values on the test set
#
# ●	Build a confusion matrix and calculate the accuracy**

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=.20, random_state=1)
rf=RandomForestClassifier(n_estimators=300)
rf.fit(x_train,y_train)
y_pred=rf.predict(x_test)

print('confusion_matrix :')
print(confusion_matrix(y_pred,y_test))
print('accuracy_score :',accuracy_score(y_test,y_pred))
# Out:
# confusion_matrix :
# [[4654  517]
#  [ 372  970]]
# accuracy_score : 0.8635037617073545
